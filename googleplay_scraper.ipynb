# %%
from google_play_scraper import app, reviews, Sort, reviews_all
import pandas as pd
import csv

# %%
scrapreview = reviews_all(
    'com.tokopedia.tkpd',
    lang='id',
    country='id',
    sort=Sort.MOST_RELEVANT,
    count=20000
)

# %%
with open('tokopedia_review.csv', mode='w', newline='', encoding='utf-8') as file:
  writer = csv.writer(file)
  writer.writerow(['Review'])
  for review in scrapreview:
    writer.writerow([review['content']])

# %%
df = pd.DataFrame(scrapreview)
df.head()
# Out:
#                                reviewId         userName  \
# 0  3a2220cd-3e1c-45c6-b3fb-8bdb8eeeb8e3  Pengguna Google
# 1  ef1c1390-ccb8-4122-9b8f-4b27cc77b17e  Pengguna Google
# 2  575d00d7-2090-42a8-8ffc-6b1056c9d158  Pengguna Google
# 3  692de8de-cddf-4443-bfde-c121baa55ee4  Pengguna Google
# 4  3f81143a-6379-4a46-9cf3-8860761d4739  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Kapok belanja di Tokopedia. Pernah beli baju d...      1            149
# 1  Tokopedia jelek banget. Diskon nya gk ada. Bar...      1            494
# 2  Terlalu banyak aturan, masa beli menggunakan a...      1            305
# 3  Kalo bisa ngasih rating - 10 pasti tak kasih b...      1            127
# 4  Udah bertahun tahun pakek tokped . Ini pengala...      1             48
#
#   reviewCreatedVersion                  at  \
# 0              3.281.0 2024-09-19 19:03:22
# 1              3.280.0 2024-09-12 07:33:28
# 2              3.279.0 2024-09-12 16:23:47
# 3              3.279.0 2024-09-10 20:26:38
# 4              3.280.0 2024-09-16 07:51:07
#
#                                         replyContent           repliedAt  \
# 0  Hi Toppers, silakan sampaikan kritik/saran ata... 2024-09-19 19:20:09
# 1  Toppers, mohon maaf atas kendala yang kamu ala... 2024-09-12 07:40:07
# 2  Halo Toppers, terima kasih atas rating yang ka... 2024-09-12 16:40:09
# 3  Hi Toppers, silakan sampaikan kritik/saran ata... 2024-09-10 21:00:27
# 4  Hi Toppers, silakan sampaikan kritik/saran ata... 2024-09-16 08:20:11
#
#   appVersion
# 0    3.281.0
# 1    3.280.0
# 2    3.279.0
# 3    3.279.0
# 4    3.280.0

# %%
df.to_csv('complete_tokopedia_review.csv')
